# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings(action='ignore') 

path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf' # 나눔 고딕
font_name = fm.FontProperties(fname=path, size=10).get_name() # 기본 폰트 사이즈 : 10
plt.rc('font', family=font_name)
fm._rebuild()

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd/content/drive/MyDrive/데이터시각화/과제3
# Out:
# /content/drive/MyDrive/데이터시각화/과제3

# %%
from matplotlib import font_manager
font_manager._rebuild()
for font in font_manager.fontManager.ttflist:
    if 'Nanum' in font.name:
        print(font.name, font.fname)

# set style
sns.set_style("dark")
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
plt.rc('font', family='NanumGothic')
plt.rc('axes', unicode_minus=False)

# %%
csv1 = pd.read_csv('서울시 한강 및 주요지천 수질 측정 자료.csv', encoding='cp949')

# %%
csv1.head()
# Out:
#          날짜     시간 측정소명    수온   pH  용존산소    총질소     총인 총유기탄소   페놀   시안
# 0  20221015  15:00   탄천  22.5  7.2   8.9  4.620  0.080   3.2  0.0  0.0
# 1  20221015  15:00  중랑천  19.8  7.4  10.7  4.700  0.125   4.4  0.0  0.0
# 2  20221015  15:00  안양천  24.6  7.4   6.7  7.320  0.070   5.4  0.0  0.0
# 3  20221015  15:00   선유  19.1  6.9   9.5  3.590  0.076   2.9  0.0  0.0
# 4  20221015  15:00  노량진  18.6  6.9   9.2  3.470  0.084   3.0  0.0  0.0

# %%
csv1_t = csv1[csv1['측정소명'] == '탄천']
csv1_j = csv1[csv1['측정소명'] == '중랑천']
csv1_a = csv1[csv1['측정소명'] == '안양천']
csv1_s = csv1[csv1['측정소명'] == '선유']
csv1_n = csv1[csv1['측정소명'] == '노량진']

# %%
csv1_t = csv1_t[csv1_t['시간'].str.contains('24:00')]
csv1_j = csv1_j[csv1_j['시간'].str.contains('24:00')]
csv1_a = csv1_a[csv1_a['시간'].str.contains('24:00')]
csv1_s = csv1_s[csv1_s['시간'].str.contains('24:00')]
csv1_n = csv1_n[csv1_n['시간'].str.contains('24:00')]

# %%
csv1_t1 = csv1_t[csv1_t['날짜'] == 20220924]
csv1_t2 = csv1_t[csv1_t['날짜'] == 20221004]
csv1_t3 = csv1_t[csv1_t['날짜'] == 20221014]
csv1_t1 = pd.concat([csv1_t1, csv1_t2, csv1_t3])

# %%
csv1_j1 = csv1_j[csv1_j['날짜'] == 20220924]
csv1_j2 = csv1_j[csv1_j['날짜'] == 20221004]
csv1_j3 = csv1_j[csv1_j['날짜'] == 20221014]
csv1_j1 = pd.concat([csv1_j1, csv1_j2, csv1_j3])

# %%
csv1_a1 = csv1_a[csv1_a['날짜'] == 20220924]
csv1_a2 = csv1_a[csv1_a['날짜'] == 20221004]
csv1_a3 = csv1_a[csv1_a['날짜'] == 20221014]
csv1_a1 = pd.concat([csv1_a1, csv1_a2, csv1_a3])

# %%
csv1_s1 = csv1_s[csv1_s['날짜'] == 20220924]
csv1_s2 = csv1_s[csv1_s['날짜'] == 20221004]
csv1_s3 = csv1_s[csv1_s['날짜'] == 20221014]
csv1_s1 = pd.concat([csv1_s1, csv1_s2, csv1_s3])

# %%
csv1_s1
# Out:
#             날짜     시간 측정소명    수온   pH 용존산소    총질소     총인 총유기탄소   페놀   시안
# 2462  20220924  24:00   선유  21.8  7.0  9.4  3.000  0.059   3.0  0.0  0.0
# 78    20221014  24:00   선유  18.1  6.9  8.8  3.530  0.069   2.9  0.0  0.0

# %%
csv1_n1 = csv1_n[csv1_n['날짜'] == 20220924]
csv1_n2 = csv1_n[csv1_n['날짜'] == 20221004]
csv1_n3 = csv1_n[csv1_n['날짜'] == 20221014]
csv1_n1 = pd.concat([csv1_n1, csv1_n2, csv1_n3])

# %%
csv1_t1['수온'] = csv1_t1['수온'].astype(float)
csv1_j1['수온'] = csv1_j1['수온'].astype(float)
csv1_s1['수온'] = csv1_s1['수온'].astype(float)
csv1_n1['수온'] = csv1_n1['수온'].astype(float)

# %%
x = np.arange(0, 3)

bar_width = 0.3

plt.figure(figsize=(12, 8))
plt.bar(x, csv1_t1['수온'], color='skyblue', width = bar_width, label='탄천')
plt.bar(x + bar_width, csv1_j1['수온'], color='yellowgreen', width = bar_width, label='중랑천')
plt.bar(x + bar_width * 2, csv1_n1['수온'], color='orange', width = bar_width, label='노량진')

plt.xticks(x + bar_width, ['9월24일', '10월4일', '10월14일'])
plt.ylabel('수온(도)')
plt.legend()
plt.title('서울 주요지천의 10일 간격 수온 변화')
plt.show()
# Out:
# <BarContainer object of 3 artists>
# <BarContainer object of 3 artists>
# <BarContainer object of 3 artists>
# ([<matplotlib.axis.XTick at 0x7f7e72dcd950>,
# ...
#  [Text(0, 0, '9월24일'), Text(0, 0, '10월4일'), Text(0, 0, '10월14일')])
# Text(0, 0.5, '수온(도)')
# Text(0.5, 1.0, '서울 주요지천의 10일 간격 수온 변화')

# %%
csv2 = pd.read_csv('국민기초생활보장+수급자(2020년+이후)_20221015153717.csv', encoding='utf-8')

# %%
csv2.head()
# Out:
#   동별(1) 동별(2) 동별(3) 총 수급자 가구 총 수급자 시설 수  총 수급자 인원 일반수급자 가구 일반수급자 인원  \
# 0    합계    소계    소계   289518        610    403311   243297   318724
# 1    본청    소계    소계        -          5       679        -        -
# 2    본청   종로구    소계     4215         14      5559     3615     4221
# 3    본청   종로구   사직동      112          -       125      105      117
# 4    본청   종로구   삼청동       38          -        45       29       31
#
#   조건부 수급자 가구 조건부 수급자 인원 특례수급자 가구 특례수급자 인원 시설수급자 시설 시설수급자 인원
# 0      40243      66245     5978     7558      610    10784
# 1          -          -        -        -        5      679
# 2        419        593      181      195       14      550
# 3          7          8        -        -        -        -
# 4          5         10        4        4        -        -

# %%
labels = ['일반 수급자', '조건부 수급자', '특례 수급자', '시설 수급자']
sizes = [243297 / 403311, 66245 / 403311, 7558 / 403311, 10784 / 403311]
colors = ['yellowgreen', 'lightskyblue', 'yellow', 'lightcoral']

fig = plt.figure(figsize=(8,8)) ## 캔버스 생성
fig.set_facecolor('white') ## 캔버스 배경색을 하얀색으로 설정
ax = fig.add_subplot() ## 프레임 생성

frequency = [243297, 66245, 7558, 10784]

pie = ax.pie(frequency, ## 파이차트 출력
       startangle=90, ## 시작점을 90도(degree)로 지정
       counterclock=False, ## 시계방향으로 그려짐
       colors = colors, ## 색상 지정
       )

total = np.sum(frequency)

threshold = 5 #상한선 비율 = 5%
sum_pct = 0 #퍼센티지

bbox_props = dict(boxstyle='square',fc='w',ec='w',alpha=0)
config = dict(arrowprops=dict(arrowstyle='-'),bbox=bbox_props,va='center')

for i,l in enumerate(labels):
    ang1, ang2 =  ax.patches[i].theta1, ax.patches[i].theta2 ## 파이의 시작 각도와 끝 각도
    center, r = ax.patches[i].center, ax.patches[i].r ## 원의 중심 좌표와 반지름길이
    
    if i < len(labels) - 1:
        sum_pct += float(f'{frequency[i]/total*100:.2f}')
        text = f'{frequency[i]/total*100:.2f}%'
    else: ## 마지막 파이 조각은 퍼센티지의 합이 100이 되도록 비율을 조절
        text = f'{100-sum_pct:.2f}%'
    
    ## 비율 상한선보다 작은 것들은 Annotation으로 만든다.
    if frequency[i]/total*100 < threshold:
        ang = (ang1+ang2)/2 ## 중심각
        x = np.cos(np.deg2rad(ang)) ## Annotation의 끝점에 해당하는 x좌표
        y = np.sin(np.deg2rad(ang)) ## Annotation의 끝점에 해당하는 y좌표
        
        ## x좌표가 양수이면 즉 y축을 중심으로 오른쪽에 있으면 왼쪽 정렬
        ## x좌표가 음수이면 즉 y축을 중심으로 왼쪽에 있으면 오른쪽 정렬
        horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
        connectionstyle = "angle,angleA=0,angleB={}".format(ang) ## 시작점과 끝점 연결 스타일
        config["arrowprops"].update({"connectionstyle": connectionstyle}) ## 
        ax.annotate(text, xy=(x, y), xytext=(1.5*x, 1.2*y),
                    horizontalalignment=horizontalalignment, **config)
    else:
        x = (r/2)*np.cos(np.pi/180*((ang1+ang2)/2)) + center[0] ## 텍스트 x좌표
        y = (r/2)*np.sin(np.pi/180*((ang1+ang2)/2)) + center[1] ## 텍스트 y좌표
        ax.text(x,y,text,ha='center',va='center',fontsize=12)


plt.title('2021년 서울특별시 국민기초생활보장 수급자의 종류와 비율')
plt.legend(pie[0],labels,loc='upper right') ## 범례
plt.show()
# Out:
# Text(0.3623032257558737, -0.3445814455348523, '74.20%')
# Text(-0.41696898290791684, 0.2759290983074046, '20.20%')
# Text(-0.4131902304352534, 1.1535749882095363, '2.31%')
# Text(-0.15471341206238667, 1.1935999356911549, '3.29%')
# Text(0.5, 1.0, '2021년 서울특별시 국민기초생활보장 수급자의 종류와 비율')

# %%
csv3 = pd.read_csv('서울시 지하철호선별 역별 승하차 인원 정보.csv', encoding='cp949')

# %%
csv3.head()
# Out:
#        사용일자    호선명        역명  승차총승객수  하차총승객수      등록일자
# 0  20221013  우이신설선  4.19민주묘지    4719    4631  20221016
# 1  20221013    경원선        가능    7603    7502  20221016
# 2  20221013    8호선      가락시장    8726    9495  20221016
# 3  20221013    3호선      가락시장   10086   10145  20221016
# 4  20221013    7호선   가산디지털단지   49231   50069  20221016

# %%
csv3['호선명'].unique()
# Out:
# array(['우이신설선', '경원선', '8호선', '3호선', '7호선', '경부선', '9호선', '경의선', '분당선',
#        '경춘선', '경인선', '2호선', '5호선', '공항철도 1호선', '경강선', '과천선', '6호선', '수인선',
#        '안산선', '신림선', '중앙선', '4호선', '일산선', '1호선', '9호선2~3단계', '장항선'],
#       dtype=object)

# %%
csv3_kk = csv3[csv3['역명'] == '건대입구']

# %%
csv3_kk.reset_index(inplace=True)

# %%
csv3_kk
# Out:
#     index      사용일자  호선명    역명  승차총승객수  하차총승객수      등록일자
# 0      28  20221013  2호선  건대입구   36952   39288  20221016
# 1      29  20221013  7호선  건대입구   14254   14930  20221016
# 2     634  20221012  2호선  건대입구   36223   38326  20221015
# 3     635  20221012  7호선  건대입구   14082   14842  20221015
# 4    1238  20221011  7호선  건대입구   14567   15044  20221014
# ..    ...       ...  ...   ...     ...     ...       ...
# 75  22449  20220906  2호선  건대입구   33912   36444  20220909
# 76  23054  20220905  2호선  건대입구   29920   31904  20220908
# 77  23055  20220905  7호선  건대입구   13601   14111  20220908
# 78  23660  20220904  2호선  건대입구   23937   24605  20220907
# 79  23661  20220904  7호선  건대입구    7660    8087  20220907
#
# [80 rows x 7 columns]

# %%
csv3_kk_2 = csv3_kk[csv3_kk['호선명'].str.contains('2')]
csv3_kk_7 = csv3_kk[csv3_kk['호선명'].str.contains('7')]

# %%
csv3_kk_2['승차총승객수'].idxmax()
print('\n')
csv3_kk_2['하차총승객수'].idxmin()
print('\n')
csv3_kk_7['승차총승객수'].idxmax()
print('\n')
csv3_kk_7['하차총승객수'].idxmin()
# Out:
# 12
# 67
# 71
# 66

# %%
csv3_kk_2.loc[[12, 67], :]
# Out:
#     index      사용일자  호선명    역명  승차총승객수  하차총승객수      등록일자
# 12   3661  20221007  2호선  건대입구   41571   45985  20221010
# 67  20024  20220910  2호선  건대입구   17511   19684  20220913

# %%
csv3_kk_7.loc[[71, 66], :]
# Out:
#     index      사용일자  호선명    역명  승차총승객수  하차총승객수      등록일자
# 71  21235  20220908  7호선  건대입구   15950   15825  20220911
# 66  20023  20220910  7호선  건대입구    4674    5145  20220913

# %%
plt.scatter(csv3_kk_2['승차총승객수'], csv3_kk_2['하차총승객수'], label='2호선', s=30, alpha=0.5)
plt.scatter(csv3_kk_7['승차총승객수'], csv3_kk_7['하차총승객수'], label='7호선', s=60, alpha=0.5)
plt.xlabel('승차 총 승객 수(명)')
plt.ylabel('하차 총 승객 수(명)')
plt.title('건대입구역 호선별 승하차 승객 수')
plt.legend()
plt.show()
# Out:
# Text(0.5, 0, '승차 총 승객 수(명)')
# Text(0, 0.5, '하차 총 승객 수(명)')
# Text(0.5, 1.0, '건대입구역 호선별 승하차 승객 수')

# %%
csv3_kk.head()
# Out:
#    index      사용일자  호선명    역명  승차총승객수  하차총승객수      등록일자
# 0     28  20221013  2호선  건대입구   36952   39288  20221016
# 1     29  20221013  7호선  건대입구   14254   14930  20221016
# 2    634  20221012  2호선  건대입구   36223   38326  20221015
# 3    635  20221012  7호선  건대입구   14082   14842  20221015
# 4   1238  20221011  7호선  건대입구   14567   15044  20221014

# %%
csv3_kk.loc[csv3_kk['호선명'] == '7호선', '하차총승객수'] = -1 * csv3_kk['하차총승객수']
csv3_kk.head()
# Out:
#    index      사용일자  호선명    역명  승차총승객수  하차총승객수      등록일자
# 0     28  20221013  2호선  건대입구   36952   39288  20221016
# 1     29  20221013  7호선  건대입구   14254  -14930  20221016
# 2    634  20221012  2호선  건대입구   36223   38326  20221015
# 3    635  20221012  7호선  건대입구   14082  -14842  20221015
# 4   1238  20221011  7호선  건대입구   14567  -15044  20221014

# %%
sns.set_theme(rc = {'figure.figsize' : (12, 14)}, font = 'NanumGothic', style = "darkgrid")
ax = sns.barplot(data= csv3_kk, x= '하차총승객수', y= '사용일자', hue= '호선명', orient= 'horizontal', dodge=False)
ax.set_xticklabels([50000, 40000, 30000, 20000, 10000, 0, 10000, 20000, 30000, 40000, 50000])
ax.set_xticks([-50000, -40000, -30000, -20000, -10000, 0, 10000, 20000, 30000, 40000, 50000])
plt.title('건대입구역 2호선 7호선 하차 총 승객 수')
plt.ylabel('날짜(연, 월, 일)')
plt.show()
# Out:
# [Text(0, 0, '50000'),
#  Text(0, 0, '40000'),
#  Text(0, 0, '30000'),
#  Text(0, 0, '20000'),
#  Text(0, 0, '10000'),
#  Text(0, 0, '0'),
#  Text(0, 0, '10000'),
#  Text(0, 0, '20000')]
# ...
# Text(0.5, 1.0, '건대입구역 2호선 7호선 하차 총 승객 수')
# Text(0, 0.5, '날짜(연, 월, 일)')

# %%
csv3_konkuk = csv3[csv3['역명'] == '건대입구']

# %%
csv3_konkuk
# Out:
#            사용일자  호선명    역명  승차총승객수  하차총승객수      등록일자
# 28     20221013  2호선  건대입구   36952   39288  20221016
# 29     20221013  7호선  건대입구   14254   14930  20221016
# 634    20221012  2호선  건대입구   36223   38326  20221015
# 635    20221012  7호선  건대입구   14082   14842  20221015
# 1238   20221011  7호선  건대입구   14567   15044  20221014
# ...         ...  ...   ...     ...     ...       ...
# 22449  20220906  2호선  건대입구   33912   36444  20220909
# 23054  20220905  2호선  건대입구   29920   31904  20220908
# 23055  20220905  7호선  건대입구   13601   14111  20220908
# 23660  20220904  2호선  건대입구   23937   24605  20220907
# 23661  20220904  7호선  건대입구    7660    8087  20220907
#
# [80 rows x 6 columns]

# %%
csv3_konkuk['총합'] = csv3_konkuk['승차총승객수'] + csv3_konkuk['하차총승객수']

# %%
csv3_konkuk
# Out:
#            사용일자  호선명    역명  승차총승객수  하차총승객수      등록일자     총합
# 28     20221013  2호선  건대입구   36952   39288  20221016  76240
# 29     20221013  7호선  건대입구   14254   14930  20221016  29184
# 634    20221012  2호선  건대입구   36223   38326  20221015  74549
# 635    20221012  7호선  건대입구   14082   14842  20221015  28924
# 1238   20221011  7호선  건대입구   14567   15044  20221014  29611
# ...         ...  ...   ...     ...     ...       ...    ...
# 22449  20220906  2호선  건대입구   33912   36444  20220909  70356
# 23054  20220905  2호선  건대입구   29920   31904  20220908  61824
# 23055  20220905  7호선  건대입구   13601   14111  20220908  27712
# 23660  20220904  2호선  건대입구   23937   24605  20220907  48542
# 23661  20220904  7호선  건대입구    7660    8087  20220907  15747
#
# [80 rows x 7 columns]

# %%
csv3_konkuk = csv3_konkuk.sort_values(by=['사용일자'])

# %%
csv3_konkuk.reset_index(inplace=True)

# %%
csv3_konkuk2 = csv3_konkuk[csv3_konkuk['호선명'] == '2호선']
csv3_konkuk7 = csv3_konkuk[csv3_konkuk['호선명'] == '7호선']

# %%
date = ['0904','0905', '0906', '0907', '0908', '0909', '0910', '0911', '0912', '0913', '0914', '0915', '0916','0917', '0918', '0919', '0920', '0921', '0922', '0923', '0924', '0925', '0926', '0927', '0928','0929', '0930', '1001', '1002', '1003', '1004', '1005', '1006', '1007', '1008', '1009', '1010','1011', '1012', '1013']

plt.figure(figsize=(14, 14))
num = np.arange(40)
plt.plot(num, csv3_konkuk2['하차총승객수'], label = '2호선')
plt.plot(num, csv3_konkuk7['하차총승객수'], label = '7호선')



plt.title('건대입구역 2호선 7호선 하차 승객 수')
plt.xticks(num, labels=date, rotation=45)
plt.ylabel('하차승객 수(명)')
plt.xlabel('날짜(월 일)')
plt.legend(loc='upeer right')
plt.show()
# Out:
# Text(0.5, 1.0, '건대입구역 2호선 7호선 하차 승객 수')
# ([<matplotlib.axis.XTick at 0x7f7e7130e390>,
# ...
#  [Text(0, 0, '0904'),
#   Text(0, 0, '0905'),
#   Text(0, 0, '0906'),
#   Text(0, 0, '0907'),
#   Text(0, 0, '0908'),
#   Text(0, 0, '0909'),
#   Text(0, 0, '0910'),
#   Text(0, 0, '0911'),
#   Text(0, 0, '0912'),
#   Text(0, 0, '0913'),
#   Text(0, 0, '0914'),
#   Text(0, 0, '0915'),
#   Text(0, 0, '0916'),
#   Text(0, 0, '0917'),
#   Text(0, 0, '0918'),
#   Text(0, 0, '0919'),
#   Text(0, 0, '0920'),
#   Text(0, 0, '0921'),
#   Text(0, 0, '0922'),
#   Text(0, 0, '0923'),
#   Text(0, 0, '0924'),
#   Text(0, 0, '0925'),
#   Text(0, 0, '0926'),
#   Text(0, 0, '0927'),
#   Text(0, 0, '0928'),
#   Text(0, 0, '0929'),
#   Text(0, 0, '0930'),
#   Text(0, 0, '1001'),
#   Text(0, 0, '1002'),
#   Text(0, 0, '1003'),
#   Text(0, 0, '1004'),
#   Text(0, 0, '1005'),
#   Text(0, 0, '1006'),
#   Text(0, 0, '1007'),
#   Text(0, 0, '1008'),
#   Text(0, 0, '1009'),
#   Text(0, 0, '1010'),
# ...

# %%
csv3_copy = csv3

# %%
csv3_copy['총합'] = csv3_copy['하차총승객수'] + csv3_copy['승차총승객수']

# %%
csv3_copy = csv3_copy.sort_values(by=['사용일자'])

# %%
csv3_g = csv3_copy[csv3_copy['역명'] == '강남']
csv3_g.reset_index(inplace=True)
csv3_g = csv3_g[5:9]
csv3_g
# Out:
#    index      사용일자  호선명  역명  승차총승객수  하차총승객수      등록일자     총합
# 5  20613  20220909  2호선  강남   28144   28180  20220912  56324
# 6  20008  20220910  2호선  강남   15881   16461  20220913  32342
# 7  19401  20220911  2호선  강남   23840   24952  20220914  48792
# 8  18795  20220912  2호선  강남   30515   29741  20220915  60256

# %%
csv3_i = csv3_copy[csv3_copy['역명'] == '이태원']
csv3_i.reset_index(inplace=True)
csv3_i = csv3_i[5:9]
csv3_i
# Out:
#    index      사용일자  호선명   역명  승차총승객수  하차총승객수      등록일자     총합
# 5  21082  20220909  6호선  이태원   12779   15675  20220912  28454
# 6  20476  20220910  6호선  이태원   10857   15038  20220913  25895
# 7  19870  20220911  6호선  이태원   13042   15526  20220914  28568
# 8  19264  20220912  6호선  이태원   10990    9293  20220915  20283

# %%
csv3_h = csv3_copy[csv3_copy['역명'] == '홍대입구']
csv3_h = csv3_h[csv3_h['호선명'] == '2호선']
csv3_h.reset_index(inplace=True)
csv3_h = csv3_h[5:9]
csv3_h
# Out:
#    index      사용일자  호선명    역명  승차총승객수  하차총승객수      등록일자      총합
# 5  21190  20220909  2호선  홍대입구   45702   48634  20220912   94336
# 6  20585  20220910  2호선  홍대입구   33802   38343  20220913   72145
# 7  19979  20220911  2호선  홍대입구   46912   53957  20220914  100869
# 8  19374  20220912  2호선  홍대입구   52548   54274  20220915  106822

# %%
csv3_k = csv3_copy[csv3_copy['역명'] == '건대입구']
csv3_k = csv3_k[csv3_k['호선명'] == '2호선']
csv3_k.reset_index(inplace=True)
csv3_k = csv3_k[5:9]
csv3_k
# Out:
#    index      사용일자  호선명    역명  승차총승객수  하차총승객수      등록일자     총합
# 5  20628  20220909  2호선  건대입구   23691   23830  20220912  47521
# 6  20024  20220910  2호선  건대입구   17511   19684  20220913  37195
# 7  19416  20220911  2호선  건대입구   23167   27848  20220914  51015
# 8  18810  20220912  2호선  건대입구   25458   28790  20220915  54248

# %%
result = pd.concat([csv3_g, csv3_i, csv3_h, csv3_k])
result
# Out:
#    index      사용일자  호선명    역명  승차총승객수  하차총승객수      등록일자      총합
# 5  20613  20220909  2호선    강남   28144   28180  20220912   56324
# 6  20008  20220910  2호선    강남   15881   16461  20220913   32342
# 7  19401  20220911  2호선    강남   23840   24952  20220914   48792
# 8  18795  20220912  2호선    강남   30515   29741  20220915   60256
# 5  21082  20220909  6호선   이태원   12779   15675  20220912   28454
# 6  20476  20220910  6호선   이태원   10857   15038  20220913   25895
# 7  19870  20220911  6호선   이태원   13042   15526  20220914   28568
# 8  19264  20220912  6호선   이태원   10990    9293  20220915   20283
# 5  21190  20220909  2호선  홍대입구   45702   48634  20220912   94336
# 6  20585  20220910  2호선  홍대입구   33802   38343  20220913   72145
# 7  19979  20220911  2호선  홍대입구   46912   53957  20220914  100869
# 8  19374  20220912  2호선  홍대입구   52548   54274  20220915  106822
# 5  20628  20220909  2호선  건대입구   23691   23830  20220912   47521
# 6  20024  20220910  2호선  건대입구   17511   19684  20220913   37195
# ...

# %%
import matplotlib.colors as mcl

from matplotlib.colors import LinearSegmentedColormap

# %%
df = pd.DataFrame([[28180, 16461, 24952, 28741], [15675, 15038, 15526, 9293], [48634, 38343, 53957, 54274], [23830, 19684, 27848, 28790]])
df.index = ['강남', '이태원', '홍대', '건대']
df.columns = ['9월 9일', '9월 10일', '9월 11일', '9월 12일']
df
# Out:
#      9월 9일  9월 10일  9월 11일  9월 12일
# 강남   28180   16461   24952   28741
# 이태원  15675   15038   15526    9293
# 홍대   48634   38343   53957   54274
# 건대   23830   19684   27848   28790

# %%
plt.rcParams['figure.figsize'] = [10, 8]

plt.pcolor(df, cmap = 'Reds')
xlab = ['0909', '0910', '0911', '0912']
ylab = ['강남', '이태원', '홍대', '건대']
plt.xticks(np.arange(0, 4), df.columns)
plt.yticks(np.arange(0, 4), df.index)
plt.title('2022년 추석연휴 주요 클럽위치지역 4곳 하차 승객 수')
plt.xlabel('날짜')
plt.ylabel('역')
plt.colorbar()

plt.show()
# Out:
# ([<matplotlib.axis.XTick at 0x7f7e71205110>,
# ...
#  [Text(0, 0, '9월 9일'),
#   Text(0, 0, '9월 10일'),
#   Text(0, 0, '9월 11일'),
#   Text(0, 0, '9월 12일')])
# ([<matplotlib.axis.YTick at 0x7f7e71204190>,
# ...
#  [Text(0, 0, '강남'), Text(0, 0, '이태원'), Text(0, 0, '홍대'), Text(0, 0, '건대')])
# Text(0.5, 1.0, '2022년 추석연휴 주요 클럽위치지역 4곳 하차 승객 수')
# Text(0.5, 0, '날짜')
# Text(0, 0.5, '역')

# %%
ax = sns.heatmap(df, annot=True, fmt='d', cmap='Reds')

plt.title('2022년 추석연휴 서울 주요 유흥지 4곳에 대한 지하철역 하차 승객 수')
plt.xlabel('날짜')
plt.ylabel('역')
plt.show()
# Out:
# Text(0.5, 1.0, '2022년 추석연휴 서울 주요 유흥지 4곳에 대한 지하철역 하차 승객 수')
# Text(0.5, 47.5, '날짜')
# Text(65.5, 0.5, '역')
